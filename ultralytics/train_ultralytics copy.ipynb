# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11.yaml")
model.train(
    data="../wastesetv2.yaml",
    epochs=100,
    imgsz=1280,
    batch=16,
    project="runs/wasteset",
    name="yolov11n_cbam"
)
# Out:
# WARNING  no model scale passed. Assuming scale='n'.
# New https://pypi.org/project/ultralytics/8.3.113 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.108  Python-3.12.6 torch-2.6.0+cpu CPU (Intel Core(TM) Ultra 9 185H)
# ...
